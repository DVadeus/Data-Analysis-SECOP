# %%
import pandas as pd

# %%
df = pd.read_parquet("data/raw/year=2024/")

# %%
df.head()
# Out:
#                                       nombre_entidad nit_entidad  \
# 0  ESE HOSPITAL DEPARTAMENTAL UNIVERSITARIO DEL Q...   800000118
# 1  HOSPITAL DEPARTAMENTAL UNIVERSITARIO SANTA SOF...   890801099
# 2  ESE HOSPITAL DEPARTAMENTAL UNIVERSITARIO DEL Q...   800000118
# 3  EMPRESA SOCIAL DEL ESTADO HOSPITAL LOCAL DE SA...   892000458
# 4  E.S.E HOSPITAL NUESTRA SEÑORA DEL CARMEN DEL C...   860020094
#
#    departamento      ciudad                           localizaci_n  \
# 0       Quindío     Armenia          Colombia,  Quindío ,  Armenia
# 1        Caldas   Manizales         Colombia,  Caldas ,  Manizales
# 2       Quindío     Armenia          Colombia,  Quindío ,  Armenia
# 3          Meta  San Martín          Colombia,  Meta ,  San Martín
# 4  Cundinamarca  El Colegio  Colombia,  Cundinamarca ,  El Colegio
#
#          orden                     sector                  rama  \
# 0     Nacional  Salud y Protección Social  Corporación Autónoma
# ...

# %%
df
